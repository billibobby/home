# %% [markdown]
# # XGBoost Stock Price Prediction Training
#
# This notebook trains an XGBoost model for stock price prediction using GPU acceleration.
#
# **Setup Instructions:**
# 1. Go to Runtime → Change runtime type
# 2. Select T4 GPU (or higher)
# 3. Click Save
# 4. Run all cells sequentially
#
# **After Training:**
# - Download the generated model files (`.json`, `.pkl`, `_metadata.json`)
# - Place them in your bot's `models/` directory
# - Update `config/config.yaml` with the model filename

# %% [markdown]
# ## 1. Setup - Check GPU and Install Dependencies

# %%
# Check GPU availability
# !nvidia-smi

# %%
# Install required libraries
# !pip install xgboost yfinance ta scikit-learn pandas numpy matplotlib joblib -q

# %%
# Import libraries
import xgboost as xgb
import yfinance as yf
import pandas as pd
import numpy as np
import ta
import matplotlib.pyplot as plt
import joblib
import json
from datetime import datetime, timedelta
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print("All imports successful!")
print(f"XGBoost version: {xgb.__version__}")
